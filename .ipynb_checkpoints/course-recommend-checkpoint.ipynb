# %%
import pandas as pd
import pickle

# Load the dataset
data = pd.read_csv("data.csv")
df= data
df.head(5)
# Out:
#                                          course_name  \
# 0  2022 Complete Python Bootcamp From Zero to Her...
# 1                    The Web Developer Bootcamp 2022
# 2         The Complete 2022 Web Development Bootcamp
# 3        Angular - The Complete Guide (2023 Edition)
# 4  Java Programming Masterclass covering Java 11 ...
#
#                                           instructor  \
# 0                                      Jose Portilla
# 1                                        Colt Steele
# 2                                      Dr. Angela Yu
# 3                           Maximilian Schwarzmüller
# 4  Tim Buchalka, Tim Buchalka's Learn Programming...
#
#                                           course url  \
# 0  https://www.udemy.com/course/complete-python-b...
# 1  https://www.udemy.com/course/the-web-developer...
# 2  https://www.udemy.com/course/the-complete-web-...
# 3  https://www.udemy.com/course/the-complete-guid...
# 4  https://www.udemy.com/course/java-the-complete...
#
#                                   course description reviews_avg  \
# 0  Learn Python like a Professional  Start from t...         4.6
# 1  COMPLETELY REDONE - The only course you need t...         4.7
# 2  Become a Full-Stack Web Developer with just ON...         4.7
# 3  Master Angular 14 (formerly "Angular 2") and b...         4.6
# 4  Learn Java In This Course And Become a Compute...         4.5
#
#    reviews_count   course_duration lectures_count       level  \
# 0       440383.0    22 total hours   155 lectures  All Levels
# 1       248508.0    64 total hours   615 lectures  All Levels
# 2       234837.0  65.5 total hours   490 lectures  All Levels
# 3       174576.0  34.5 total hours   472 lectures  All Levels
# 4       171838.0  80.5 total hours   401 lectures  All Levels
#
#        students_count
# 0  1,629,692 students
# 1    830,559 students
# 2    794,897 students
# 3    634,196 students
# 4    727,934 students

# %%
df.shape
# Out:
# (8543, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8543 entries, 0 to 8542
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   course_name         8532 non-null   object
#  1   instructor          8535 non-null   object
#  2   course url          8539 non-null   object
#  3   course description  8535 non-null   object
#  4   reviews_avg         8454 non-null   object
#  5   reviews_count       8530 non-null   float64
#  6   course_duration     8530 non-null   object
#  7   lectures_count      8530 non-null   object
#  8   level               8486 non-null   object
#  9   students_count      8528 non-null   object
# dtypes: float64(1), object(9)
# memory usage: 667.6+ KB

# %%
df.isnull().sum()
# Out:
# course_name           11
# instructor             8
# course url             4
# course description     8
# reviews_avg           89
# reviews_count         13
# course_duration       13
# lectures_count        13
# level                 57
# students_count        15
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
# Clean and preprocess the data
df = df[['course_name', 'instructor', 'course url', 'reviews_avg','course description']]
# Extract numerical ratings from 'reviews_avg' column
df['rating'] = df['reviews_avg'].str.extract(r'(\d+\.\d+)')
df['rating'] = df['rating'].astype(float)

# Drop rows with missing values in 'rating' column
df = df.dropna(subset=['rating'])
# Display the first few rows of the preprocessed DataFrame
df.head(5)
# Out:
# C:\Users\91935\AppData\Local\Temp\ipykernel_2600\2701155325.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['reviews_avg'].str.extract(r'(\d+\.\d+)')
# C:\Users\91935\AppData\Local\Temp\ipykernel_2600\2701155325.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['rating'] = df['rating'].astype(float)
#                                          course_name  \
# 0  2022 Complete Python Bootcamp From Zero to Her...
# 1                    The Web Developer Bootcamp 2022
# 2         The Complete 2022 Web Development Bootcamp
# 3        Angular - The Complete Guide (2023 Edition)
# 4  Java Programming Masterclass covering Java 11 ...
#
#                                           instructor  \
# 0                                      Jose Portilla
# 1                                        Colt Steele
# 2                                      Dr. Angela Yu
# 3                           Maximilian Schwarzmüller
# 4  Tim Buchalka, Tim Buchalka's Learn Programming...
#
#                                           course url reviews_avg  \
# 0  https://www.udemy.com/course/complete-python-b...         4.6
# 1  https://www.udemy.com/course/the-web-developer...         4.7
# 2  https://www.udemy.com/course/the-complete-web-...         4.7
# 3  https://www.udemy.com/course/the-complete-guid...         4.6
# 4  https://www.udemy.com/course/java-the-complete...         4.5
#
#                                   course description  rating
# 0  Learn Python like a Professional  Start from t...     4.6
# 1  COMPLETELY REDONE - The only course you need t...     4.7
# 2  Become a Full-Stack Web Developer with just ON...     4.7
# 3  Master Angular 14 (formerly "Angular 2") and b...     4.6
# 4  Learn Java In This Course And Become a Compute...     4.5

# %%
# Drop rows with missing values in the 'course_name' and 'reviews_avg' columns
df_cleaned = df.dropna(subset=['course_name', 'reviews_avg','course description'])
# Extract ratings from the 'reviews_avg' column and convert them to numeric
df_cleaned['rating'] = df_cleaned['reviews_avg'].str.extract('(\d+\.\d+)', expand=False).astype(float)

df=df.drop(['reviews_avg'],axis=1)
df_cleaned.head(10)
# Out:
#                                          course_name  \
# 0  2022 Complete Python Bootcamp From Zero to Her...
# 1                    The Web Developer Bootcamp 2022
# 2         The Complete 2022 Web Development Bootcamp
# 3        Angular - The Complete Guide (2023 Edition)
# 4  Java Programming Masterclass covering Java 11 ...
# 5  React - The Complete Guide (incl Hooks, React ...
# 6  Machine Learning A-Z™: Hands-On Python & R In ...
# 7  The Complete JavaScript Course 2023: From Zero...
# 8  100 Days of Code: The Complete Python Pro Boot...
# 9  Python for Data Science and Machine Learning B...
#
#                                           instructor  \
# 0                                      Jose Portilla
# 1                                        Colt Steele
# 2                                      Dr. Angela Yu
# 3                           Maximilian Schwarzmüller
# 4  Tim Buchalka, Tim Buchalka's Learn Programming...
# 5  Academind by Maximilian Schwarzmüller, Maximil...
# 6  Kirill Eremenko, Hadelin de Ponteves, Ligency ...
# 7                                  Jonas Schmedtmann
# 8                                      Dr. Angela Yu
# 9                                      Jose Portilla
#
#                                           course url reviews_avg  \
# 0  https://www.udemy.com/course/complete-python-b...         4.6
# 1  https://www.udemy.com/course/the-web-developer...         4.7
# 2  https://www.udemy.com/course/the-complete-web-...         4.7
# 3  https://www.udemy.com/course/the-complete-guid...         4.6
# 4  https://www.udemy.com/course/java-the-complete...         4.5
# 5  https://www.udemy.com/course/react-the-complet...         4.6
# 6      https://www.udemy.com/course/machinelearning/         4.5
# 7  https://www.udemy.com/course/the-complete-java...         4.7
# 8     https://www.udemy.com/course/100-days-of-code/         4.7
# 9  https://www.udemy.com/course/python-for-data-s...         4.6
#
#                                   course description  rating
# 0  Learn Python like a Professional  Start from t...     4.6
# 1  COMPLETELY REDONE - The only course you need t...     4.7
# 2  Become a Full-Stack Web Developer with just ON...     4.7
# 3  Master Angular 14 (formerly "Angular 2") and b...     4.6
# 4  Learn Java In This Course And Become a Compute...     4.5
# 5  Dive in and learn React.js from scratch! Learn...     4.6
# 6  Learn to create Machine Learning Algorithms in...     4.5
# 7  The modern JavaScript course for everyone! Mas...     4.7
# 8  Master Python by building 100 projects in 100 ...     4.7
# 9  Learn how to use NumPy, Pandas, Seaborn , Matp...     4.6

# %%
def recommend_courses_by_keyword(keyword, df, num_courses=5):
    # Filter courses based on whether their name contains the keyword
    relevant_courses = df[df['course_name'].str.contains(keyword, case=False)]

    # Sort relevant courses by ratings in descending order
    sorted_courses = relevant_courses.sort_values(by='rating', ascending=False)

    # Get top courses
    top_courses = sorted_courses.head(num_courses)
    tpc = top_courses[['course_name','course url']]
    return tpc
# Test the recommendation function with different keywords
keywords = [ 'java']
for keyword in keywords:
    recommended_courses = recommend_courses_by_keyword(keyword, df_cleaned)
    print(f"\nTop courses related to '{keyword}':")
    print(recommended_courses)
# Out:
# Top courses related to 'java':
#                                             course_name  \
# 2831  *UPDATED* DOM 2022 Build Dynamic Websites Java...
# 2694                         Test your Core Java skills
# 4294                        Mastering JavaScript Arrays
# 6399                          Java Decision Programming
# 3368      Learn Java Programming - Beginners guide 2022
#
#                                              course url
# 2831  https://www.udemy.com/course/build-dynamic-web...
# 2694         https://www.udemy.com/course/testcorejava/
# 4294  https://www.udemy.com/course/mastering-javascr...
# 6399  https://www.coursera.org/learn/java-decison-pr...
# 3368  https://www.udemy.com/course/learn-java-progra...

# %%
pickle.dump(df,open('df.pkl','wb'))

# %%
data.head(3)
# Out:
#                                          course_name     instructor  \
# 0  2022 Complete Python Bootcamp From Zero to Her...  Jose Portilla
# 1                    The Web Developer Bootcamp 2022    Colt Steele
# 2         The Complete 2022 Web Development Bootcamp  Dr. Angela Yu
#
#                                           course url  \
# 0  https://www.udemy.com/course/complete-python-b...
# 1  https://www.udemy.com/course/the-web-developer...
# 2  https://www.udemy.com/course/the-complete-web-...
#
#                                   course description reviews_avg  \
# 0  Learn Python like a Professional  Start from t...         4.6
# 1  COMPLETELY REDONE - The only course you need t...         4.7
# 2  Become a Full-Stack Web Developer with just ON...         4.7
#
#    reviews_count   course_duration lectures_count       level  \
# 0       440383.0    22 total hours   155 lectures  All Levels
# 1       248508.0    64 total hours   615 lectures  All Levels
# 2       234837.0  65.5 total hours   490 lectures  All Levels
#
#        students_count
# 0  1,629,692 students
# 1    830,559 students
# 2    794,897 students

# %%
data.dropna(inplace=True)

# %%
popular_df = data[['course_name','course url','course description','reviews_avg','reviews_count']]
popular_df['reviews_avg']=popular_df['reviews_avg'].astype(float)
popular_df['reviews_count']=popular_df['reviews_count'].astype(float)
# Out:
# C:\Users\91935\AppData\Local\Temp\ipykernel_2600\2654405414.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popular_df['reviews_avg']=popular_df['reviews_avg'].astype(float)
# C:\Users\91935\AppData\Local\Temp\ipykernel_2600\2654405414.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   popular_df['reviews_count']=popular_df['reviews_count'].astype(float)

# %%
popular_df = data[data['reviews_count']>=10000].sort_values('reviews_avg',ascending=False).head(50)

# %%
popular_df
# Out:
#                                             course_name  \
# 5217  AWS Elastic Beanstalk:Deploy a Python(Flask) W...
# 5096                           Animals and Institutions
# 5319                Encryption And Decryption Using C++
# 5163        Tracking Student Growth using Google Slides
# 5048  AWS Elastic Beanstalk: Build & Deploy a Node.j...
# 5048  In this 1-hour long project-based course, you ...           5
# 5054  Learners will present a well-organized academi...           5
# 5130  In this course, students will understand chara...           5
# 5081  By the end of this guided project, you will be...           5
# 5090  In this one-hour, project-based course, you'll...           5
# 5047  The way we currently pay our care providers le...         4.9
# 5028  This course is an introduction to the basic co...         4.9
# 5050  This course has four modules, or foci.  The fi...         4.9
# 5204  The present course gives an overview of Bases ...         4.9
# 5311  Students will produce a networked game that wi...         4.9
# 5122  Welcome to Voice Disorders: What Patients and ...         4.9
# 5340  Optimization is a common form of decision maki...         4.9
# 5250  This course is for early career researchers an...         4.9
# 5151  At a time when information can be instantaneou...         4.9
# 5139  By the end of this project, you will have set ...         4.9
# 5076  In the education of children with visual impai...         4.9
# 5269  You�ll never have a complete picture of what's...         4.9
# 5138  This Specialization is aimed at preparing stud...         4.9
# 5168  Of all the animals on earth, which are the str...         4.9
# 5094  This course can also be taken for academic cre...         4.8
# 5239  Spreadsheet software remains one of the most u...         4.8
# 5234  The new version of Introduction to Ableton Liv...         4.8
# 5237  Taking, sharing, and viewing photographs has b...         4.8
# 5277  Explore the art of record production and how t...         4.8
# 5276  Explore the art of record production and how t...         4.8
# 5275  This is a basic course in designing experiment...         4.8
# 5102  While the human genome sequence has transforme...         4.8
# 5073  Welcome to School Health specialization: Manag...         4.8
# 218   Learn NextJS from the ground up and build prod...         4.8
# 5255  This course introduces the basics of cyber def...         4.8
# 5242  Accountants perform a wide variety of activiti...         4.8
# 5101  The course is a comprehensive set of didactic ...         4.8
# 5265  This course equips you with critical content c...         4.8
# 5248  Environmental law may be the one institution s...         4.8
# 5228  Successful decision making is based on three k...         4.8
# 5258  Palliative care provides important support for...         4.8
# 5252  Managing a company in the food and beverage in...         4.8
# 5233  The new version of Introduction to Ableton Liv...         4.8
# 5078  In this course, you will learn how to solve pr...         4.8
# 5226  Science is undergoing a data explosion, and as...         4.8
# 213   Variables, Functions and Functional Programmin...         4.8
# 5144  This course builds on previous concepts and ou...         4.8
# 5158  This course, part 2 of a 2-course sequence, ex...         4.8
# 5141  This course is an introduction to the notion o...         4.8
# 5169  In this project you will learn how to use segm...         4.8
# 5172  Graphic design is telling a story by using bot...         4.8
#
#       reviews_count   course_duration lectures_count         level  \
# 5217         9609.0    44 total hours   290 lectures      Beginner
# 5096        23745.0  39.5 total hours   328 lectures      Beginner
# 5319         5965.0    31 total hours   222 lectures      Beginner
# 5163        13312.0    17 total hours   126 lectures      Beginner
# 5048        56394.0    32 total hours   329 lectures      Advanced
# 5054        45652.0    29 total hours   217 lectures      Advanced
# 5130        17049.0    27 total hours   310 lectures      Advanced
# 5081        28430.0  32.5 total hours   272 lectures      Advanced
# 5090        25730.0      1 total hour    13 lectures      Advanced
# 5047        56703.0    20 total hours   180 lectures      Advanced
# 5028       156031.0    69 total hours   320 lectures  Intermediate
# 5050        53453.0    46 total hours   305 lectures      Advanced
# 5204        10229.0   6.5 total hours    87 lectures  Intermediate
# 5311         6175.0    23 total hours   235 lectures      Advanced
# 5122        18398.0    21 total hours   110 lectures  Intermediate
# 5340         5509.0  17.5 total hours   111 lectures      Advanced
